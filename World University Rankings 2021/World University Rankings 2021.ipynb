# %%
from const import *
import urllib.request
import json

# %%
# 从XHR中找json文件
url = 'https://www.timeshighereducation.com/sites/default/files/the_data_rankings/world_university_rankings_2021_0__fa224219a267a5b9c4287386a97c70ea.json'

request = urllib.request.Request(url, headers=HEADERS)
res = urllib.request.urlopen(request)
data = res.read().decode('utf-8')

data = json.loads(data)
data
# Out:
# {'data': [{'rank_order': '10',
#    'rank': '1',
#    'name': 'University of Oxford',
#    'scores_overall': '95.6',
#    'scores_overall_rank': '10',
#    'scores_teaching': '91.3',
#    'scores_teaching_rank': '5',
#    'scores_research': '99.6',
#    'scores_research_rank': '1',
#    'scores_citations': '98.0',
#    'scores_citations_rank': '37',
#    'scores_industry_income': '68.7',
#    'scores_industry_income_rank': '189',
#    'scores_international_outlook': '96.4',
#    'scores_international_outlook_rank': '24',
#    'record_type': 'master_account',
#    'member_level': '0',
#    'url': '/world-university-rankings/university-oxford',
#    'nid': 468,
#    'location': 'United Kingdom',
#    'stats_number_students': '20,774',
#    'stats_student_staff_ratio': '11.1',
#    'stats_pc_intl_students': '41%',
#    'stats_female_male_ratio': '46 : 54',
#    'aliases': 'University of Oxford',
# ...

# %%
uni = data['data']
len(uni)
# Out:
# 1527

# %%
type(uni[0])
# Out:
# dict

# %%
result = []
info = ['rank', 'name', 'location', 'stats_number_students', 'stats_student_staff_ratio', 'stats_pc_intl_students', 'stats_female_male_ratio',
        'scores_overall', 'scores_teaching', 'scores_research', 'scores_citations', 'scores_industry_income', 'scores_international_outlook']
for u in uni:
    result.append([u[i] for i in info])
    result[-1][0] = ' ' + result[-1][0]
result
# Out:
# [[' 1',
#   'University of Oxford',
#   'United Kingdom',
#   '20,774',
#   '11.1',
#   '41%',
#   '46 : 54',
#   '95.6',
#   '91.3',
#   '99.6',
#   '98.0',
#   '68.7',
#   '96.4'],
#  [' 2',
#   'Stanford University',
#   'United States',
#   '16,223',
#   '7.4',
#   '23%',
#   '44 : 56',
#   '94.9',
#   '92.2',
#   '96.7',
#   '99.9',
#   '90.1',
#   '79.5'],
#  [' 3',
#   'Harvard University',
#   'United States',
#   '21,261',
#   '9.3',
#   '25%',
#   '49 : 51',
#   '94.8',
#   '94.4',
#   '98.8',
#   '99.4',
#   '46.8',
#   '77.7'],
#  [' 4',
#   'California Institute of Technology',
#   'United States',
#   '2,238',
#   '6.3',
#   '33%',
#   '36 : 64',
#   '94.5',
#   '92.5',
#   '96.9',
#   '97.0',
#   '92.7',
#   '83.6'],
#  [' 5',
#   'Massachusetts Institute of Technology',
#   'United States',
#   '11,276',
#   '8.4',
#   '34%',
#   '39 : 61',
#   '94.4',
#   '90.7',
#   '94.4',
#   '99.7',
#   '90.4',
#   '90.0'],
#  [' 6',
#   'University of Cambridge',
# ...

# %%
len(result)
# Out:
# 1527

# %%
import pandas as pd
columns = ['Rank', 'Name', 'Location', 'No. of FTE Students', 'No. of students per staff', 'International Students', 'Female:Male Ratio',
          'Overall', 'Teaching', 'Research', 'Citations', 'Industry Income', 'International Outlook']
df = pd.DataFrame(result, columns=columns) 
df
# Out:
#         Rank                                            Name        Location  \
# 0          1                            University of Oxford  United Kingdom
# 1          2                             Stanford University   United States
# 2          3                              Harvard University   United States
# 3          4              California Institute of Technology   United States
# 4          5           Massachusetts Institute of Technology   United States
# ...      ...                                             ...             ...
# 1522   1001+                              Yuan Ze University          Taiwan
# 1523   1001+  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1524   1001+                              Zagazig University           Egypt
# 1525   1001+                            University of Zagreb         Croatia
# 1526   1001+                            University of Žilina        Slovakia
#
# ...

# %%
df.to_excel('ranking.xlsx',index=False)
